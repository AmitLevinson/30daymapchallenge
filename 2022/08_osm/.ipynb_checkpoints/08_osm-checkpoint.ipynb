# %%
import osmnx as ox
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib import font_manager

# %%
city_name = 'Rehovot, IL'

# %%
# Not necessary, I mainly us it for the plot's borders
rehovot_sf = gpd.read_file('rehovot_sf/gv_Rehovot_2016_plt.shp', encoding = 'utf-8')
rehovot_sf = rehovot_sf.to_crs(4326)
xmin, ymin, xmax, ymax = rehovot_sf.total_bounds

# %%
roads = ox.graph_from_place('Rehovot, IL',network_type='drive')

# %%
font_path = 'C:\Windows\Fonts\KaushanScript-Regular.ttf'  # Your font path goes here
font_manager.fontManager.addfont(font_path)
prop = font_manager.FontProperties(fname=font_path)

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = prop.get_name()

# %%
fig, ax = ox.plot_graph(
    roads,
	node_size=0,
	edge_linewidth=1,
	edge_color='gold', show=False, close = False, figsize = (14,22))

ax.set_facecolor('black')
ax.set_xlim(xmin-0.001, xmax+0.001)
ax.set_ylim(ymin, ymax+0.001)
plt.text(xmin + 0.0025, ymax - 0.01, 'Roads & streets\nin Rehovot, IL', color = 'white', fontsize= 38, weight='bold')
plt.text(xmax - 0.06, ymin + 0.001, 'Data: OpenStreetMap $\cdot$ Amit Grinson', color = 'white', fontsize= 16)

plt.savefig('rehovot.png', bbox_inches='tight', dpi = 500)
plt.show()
